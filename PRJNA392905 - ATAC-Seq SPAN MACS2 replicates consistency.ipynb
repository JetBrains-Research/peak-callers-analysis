# %% [markdown]
# # PRJNA392905 - ATAC-Seq SPAN, MACS2 replicates consistency
#
# Logbook: https://docs.google.com/document/d/1WxzLWUX0PV2TpD0VfwStHczN6YSQ35Uu6DDR-8WX-io/edit#heading=h.xg4nq1px6lhh
#
# Figures: https://docs.google.com/presentation/d/1jNKqioqQrTuUBw_n4uPxpm3behA_j77rK_xwTilrjpc/edit#slide=id.g4e80133e1e_0_5

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

from IPython.display import display
import pandas as pd

import seaborn as sns
sns.set_style("whitegrid")
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import numpy as np
import scipy as sp
import os
import glob
from pybedtools import BedTool

NAMES = ['Thymus_gdT_Cell', 'Spleen_CD8_T_Cell', 'Blood_Monocyte']
def file_to_name(file):
    for n in range(2692210, 2692216):
        if 'GSM{}'.format(n) in file:
            return 'Thymus_gdT_Cell'
    for n in range(2692222, 2692232):
        if 'GSM{}'.format(n) in file:
            return 'Spleen_CD8_T_Cell'
    return 'Blood_Monocyte'

# %% [markdown]
# # Macs2
# 1. Place BAM files of interest to
# 2. Iterate over P values
# ```
# for P in 0.1 0.01 0.001 0.0001; do echo $P; bash /mnt/stripe/washu/parallel/macs2.sh mm10 /mnt/stripe/bio/genomes/mm10/mm10.chrom.sizes "p${P}" "--p ${P}" $(pwd); done  | tee log.txt
# ```
# 3. Iterate over Q values
# ```
# for Q in 0.1 0.01 0.001 0.0001; do echo $Q; bash /mnt/stripe/washu/parallel/macs2.sh mm10 /mnt/stripe/bio/genomes/mm10/mm10.chrom.sizes "q${Q}" "--q ${Q}" $(pwd); done  | tee log.txt
# ```

# %%
MACS2_FOLDER='/mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2'
# LEVELS = ['p0.1', 'p0.01', 'p0.001', 'p0.0001', 'q0.1', 'q0.01', 'q0.001', 'q0.0001']
LEVELS = ['q0.1', 'q0.01', 'q0.001', 'q0.0001']

dfm = pd.DataFrame(columns=['name', 'level', 'file', 'peaks'])

for file in glob.glob(MACS2_FOLDER + '/*.narrowPeak'):
    level = next((l for l in LEVELS if '_{}_'.format(l) in file), None)
    if level:
        print('Processing', file)
        name = file_to_name(file)
        dfm.loc[len(dfm)] = (name, level, file, int(BedTool(file).count()))

display(dfm.head())
# Out:
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692228_Spleen_CD8_T_Cell_ATAC_seq_mm10_q0.1_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692215_Thymus_gdT_Cell_ATAC_seq_mm10_q0.1_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692227_Spleen_CD8_T_Cell_ATAC_seq_mm10_q0.1_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692229_Spleen_CD8_T_Cell_ATAC_seq_mm10_q0.1_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692223_Spleen_CD8_T_Cell_ATAC_seq_mm10_q0.1_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692230_Spleen_CD8_T_Cell_ATAC_seq_mm10_q0.1_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692211_Thymus_gdT_Cell_ATAC_seq_mm10_q0.1_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692225_Spleen_CD8_T_Cell_ATAC_seq_mm10_q0.1_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692279_Blood_Monocyte_ATAC_seq_mm10_q0.1_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692280_Blood_Monocyte_ATAC_seq_mm10_q0.1_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692210_Thymus_gdT_Cell_ATAC_seq_mm10_q0.1_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692231_Spleen_CD8_T_Cell_ATAC_seq_mm10_q0.1_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692281_Blood_Monocyte_ATAC_seq_mm10_q0.1_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692282_Blood_Monocyte_ATAC_seq_mm10_q0.1_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692212_Thymus_gdT_Cell_ATAC_seq_mm10_q0.1_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692214_Thymus_gdT_Cell_ATAC_seq_mm10_q0.1_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692222_Spleen_CD8_T_Cell_ATAC_seq_mm10_q0.1_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692213_Thymus_gdT_Cell_ATAC_seq_mm10_q0.1_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692226_Spleen_CD8_T_Cell_ATAC_seq_mm10_q0.1_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692224_Spleen_CD8_T_Cell_ATAC_seq_mm10_q0.1_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692329_Blood_Monocyte_ATAC_seq_mm10_q0.1_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692330_Blood_Monocyte_ATAC_seq_mm10_q0.1_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692228_Spleen_CD8_T_Cell_ATAC_seq_mm10_q0.01_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692227_Spleen_CD8_T_Cell_ATAC_seq_mm10_q0.01_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692215_Thymus_gdT_Cell_ATAC_seq_mm10_q0.01_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692211_Thymus_gdT_Cell_ATAC_seq_mm10_q0.01_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692225_Spleen_CD8_T_Cell_ATAC_seq_mm10_q0.01_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692223_Spleen_CD8_T_Cell_ATAC_seq_mm10_q0.01_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692229_Spleen_CD8_T_Cell_ATAC_seq_mm10_q0.01_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692210_Thymus_gdT_Cell_ATAC_seq_mm10_q0.01_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692280_Blood_Monocyte_ATAC_seq_mm10_q0.01_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692230_Spleen_CD8_T_Cell_ATAC_seq_mm10_q0.01_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692279_Blood_Monocyte_ATAC_seq_mm10_q0.01_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692212_Thymus_gdT_Cell_ATAC_seq_mm10_q0.01_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692213_Thymus_gdT_Cell_ATAC_seq_mm10_q0.01_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692226_Spleen_CD8_T_Cell_ATAC_seq_mm10_q0.01_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692214_Thymus_gdT_Cell_ATAC_seq_mm10_q0.01_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692231_Spleen_CD8_T_Cell_ATAC_seq_mm10_q0.01_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692282_Blood_Monocyte_ATAC_seq_mm10_q0.01_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692222_Spleen_CD8_T_Cell_ATAC_seq_mm10_q0.01_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692281_Blood_Monocyte_ATAC_seq_mm10_q0.01_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692224_Spleen_CD8_T_Cell_ATAC_seq_mm10_q0.01_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692329_Blood_Monocyte_ATAC_seq_mm10_q0.01_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692330_Blood_Monocyte_ATAC_seq_mm10_q0.01_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692228_Spleen_CD8_T_Cell_ATAC_seq_mm10_q0.001_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692227_Spleen_CD8_T_Cell_ATAC_seq_mm10_q0.001_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692215_Thymus_gdT_Cell_ATAC_seq_mm10_q0.001_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692229_Spleen_CD8_T_Cell_ATAC_seq_mm10_q0.001_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692230_Spleen_CD8_T_Cell_ATAC_seq_mm10_q0.001_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692223_Spleen_CD8_T_Cell_ATAC_seq_mm10_q0.001_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692210_Thymus_gdT_Cell_ATAC_seq_mm10_q0.001_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692211_Thymus_gdT_Cell_ATAC_seq_mm10_q0.001_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692280_Blood_Monocyte_ATAC_seq_mm10_q0.001_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692225_Spleen_CD8_T_Cell_ATAC_seq_mm10_q0.001_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692279_Blood_Monocyte_ATAC_seq_mm10_q0.001_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692212_Thymus_gdT_Cell_ATAC_seq_mm10_q0.001_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692214_Thymus_gdT_Cell_ATAC_seq_mm10_q0.001_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692213_Thymus_gdT_Cell_ATAC_seq_mm10_q0.001_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692281_Blood_Monocyte_ATAC_seq_mm10_q0.001_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692282_Blood_Monocyte_ATAC_seq_mm10_q0.001_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692231_Spleen_CD8_T_Cell_ATAC_seq_mm10_q0.001_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692222_Spleen_CD8_T_Cell_ATAC_seq_mm10_q0.001_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692226_Spleen_CD8_T_Cell_ATAC_seq_mm10_q0.001_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692224_Spleen_CD8_T_Cell_ATAC_seq_mm10_q0.001_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692329_Blood_Monocyte_ATAC_seq_mm10_q0.001_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692330_Blood_Monocyte_ATAC_seq_mm10_q0.001_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692215_Thymus_gdT_Cell_ATAC_seq_mm10_q0.0001_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692228_Spleen_CD8_T_Cell_ATAC_seq_mm10_q0.0001_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692227_Spleen_CD8_T_Cell_ATAC_seq_mm10_q0.0001_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692211_Thymus_gdT_Cell_ATAC_seq_mm10_q0.0001_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692225_Spleen_CD8_T_Cell_ATAC_seq_mm10_q0.0001_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692280_Blood_Monocyte_ATAC_seq_mm10_q0.0001_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692210_Thymus_gdT_Cell_ATAC_seq_mm10_q0.0001_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692229_Spleen_CD8_T_Cell_ATAC_seq_mm10_q0.0001_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692223_Spleen_CD8_T_Cell_ATAC_seq_mm10_q0.0001_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692230_Spleen_CD8_T_Cell_ATAC_seq_mm10_q0.0001_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692279_Blood_Monocyte_ATAC_seq_mm10_q0.0001_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692214_Thymus_gdT_Cell_ATAC_seq_mm10_q0.0001_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692213_Thymus_gdT_Cell_ATAC_seq_mm10_q0.0001_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692281_Blood_Monocyte_ATAC_seq_mm10_q0.0001_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692212_Thymus_gdT_Cell_ATAC_seq_mm10_q0.0001_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692231_Spleen_CD8_T_Cell_ATAC_seq_mm10_q0.0001_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692222_Spleen_CD8_T_Cell_ATAC_seq_mm10_q0.0001_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692282_Blood_Monocyte_ATAC_seq_mm10_q0.0001_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692226_Spleen_CD8_T_Cell_ATAC_seq_mm10_q0.0001_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692224_Spleen_CD8_T_Cell_ATAC_seq_mm10_q0.0001_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692329_Blood_Monocyte_ATAC_seq_mm10_q0.0001_peaks.narrowPeak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_macs2/GSM2692330_Blood_Monocyte_ATAC_seq_mm10_q0.0001_peaks.narrowPeak
#                 name level                                               file  \
# 0  Spleen_CD8_T_Cell  q0.1  /mnt/stripe/bio/raw-data/geo-samples/PRJNA3929...
# 1    Thymus_gdT_Cell  q0.1  /mnt/stripe/bio/raw-data/geo-samples/PRJNA3929...
# 2  Spleen_CD8_T_Cell  q0.1  /mnt/stripe/bio/raw-data/geo-samples/PRJNA3929...
# 3  Spleen_CD8_T_Cell  q0.1  /mnt/stripe/bio/raw-data/geo-samples/PRJNA3929...
# 4  Spleen_CD8_T_Cell  q0.1  /mnt/stripe/bio/raw-data/geo-samples/PRJNA3929...
#
#    peaks
# 0  37583
# 1  57507
# 2  34896
# 3  32901
# 4  48657

# %%
dfm['peaks'] = [int(x) for x in dfm['peaks']]
dfm.groupby(['name', 'level'])['peaks'].mean()
# Out:
# name               level
# Blood_Monocyte     q0.0001    16856.333333
#                    q0.001     20839.000000
#                    q0.01      26945.333333
#                    q0.1       38292.666667
# Spleen_CD8_T_Cell  q0.0001    15424.400000
#                    q0.001     18663.700000
#                    q0.01      23380.000000
#                    q0.1       33496.500000
# Thymus_gdT_Cell    q0.0001    11154.833333
#                    q0.001     14621.500000
#                    q0.01      20858.500000
#                    q0.1       33748.333333
# Name: peaks, dtype: float64

# %% [markdown]
# ##  MACS2 peaks graphics

# %%
def show_peaks(df, levels, log=True, ymax=None):
    level_ranks = {l:i for i,l in enumerate(levels)}  
    df['params'] = df['level'].map(level_ranks)
    df.sort_values(['params'], inplace=True)
    print([(l,i) for i,l in enumerate(levels)])
    
    # Plot log peaks number
    if log:
        df['peaks_log'] = np.log(df['peaks'])
    plt.figure(figsize=(11, 8))
    g = sns.lineplot(x="params", y="peaks_log" if log else "peaks",
                     hue="name", markers=True, style="name", ci=100, 
                     data=df)
    g.set(ylim=(0, ymax))
    g.set(xticks=np.arange(0,len(level_ranks)))
    g.set(xticklabels=levels)
    plt.show()
    # now drop the 'params' column
    df.drop(labels=['params'],axis=1, inplace=True)
    if log:
        df.drop(labels=['peaks_log'],axis=1, inplace=True)

# %%
show_peaks(dfm, LEVELS, log=False, ymax=70000)
# Out:
# [('q0.1', 0), ('q0.01', 1), ('q0.001', 2), ('q0.0001', 3)]

# %% [markdown]
# ## Compute overlap MACS2

# %%
from pathlib import Path
import downstream.bed_metrics as bm

def overlap_with_name_level(overlaps, n, l):
    dfo = overlaps[(n, l)].melt(value_name='overlap')
    dfo['name'] = n
    dfo['level'] = l
    return dfo


def show_overlap(df, levels, tool, ymax=None):
    overlaps = {}
    for n in NAMES:
        for l in levels:
            print('Processing', n, l)
            files = df.loc[np.logical_and(df['name'] == n, df['level'] == l)]['file']
            paths = [Path(f) for f in files]
            df_path = '/tmp/overlap_{}_{}_{}.tsv'.format(tool, n, l)
            overlaps[(n, l)] = bm.load_or_build_metrics_table(paths, paths, Path(df_path), jaccard=False)

    dfoverlap = pd.concat([overlap_with_name_level(overlaps, n, l) for (n, l) in overlaps])        
    dfoverlap.head()

    level_ranks = {l:i for i,l in enumerate(levels)}  
    dfoverlap['params'] = dfoverlap['level'].map(level_ranks)
    dfoverlap.sort_values(['params'], inplace=True)
    print([(l,i) for i,l in enumerate(levels)])

    # Plot overlaps
    plt.figure(figsize=(11, 8))
    g = sns.lineplot(x="params", y="overlap",
                 hue="name", markers=True, style="name", ci=100, 
                 data=dfoverlap)
    g.set(ylim=(0, ymax))
    g.set(xticks=np.arange(0,len(level_ranks)))
    g.set(xticklabels=levels)
    plt.show()
    # now drop the 'params' column
    dfoverlap.drop(labels=['params'], axis=1, inplace=True)

# %%
show_overlap(dfm, LEVELS, 'macs2', ymax=0.9)
# Out:
# Processing Thymus_gdT_Cell q0.1
# [Skipped]: Already exists /tmp/overlap_macs2_Thymus_gdT_Cell_q0.1.tsv
# Processing Thymus_gdT_Cell q0.01
# [Skipped]: Already exists /tmp/overlap_macs2_Thymus_gdT_Cell_q0.01.tsv
# Processing Thymus_gdT_Cell q0.001
# [Skipped]: Already exists /tmp/overlap_macs2_Thymus_gdT_Cell_q0.001.tsv
# Processing Thymus_gdT_Cell q0.0001
# [Skipped]: Already exists /tmp/overlap_macs2_Thymus_gdT_Cell_q0.0001.tsv
# Processing Spleen_CD8_T_Cell q0.1
# [Skipped]: Already exists /tmp/overlap_macs2_Spleen_CD8_T_Cell_q0.1.tsv
# Processing Spleen_CD8_T_Cell q0.01
# [Skipped]: Already exists /tmp/overlap_macs2_Spleen_CD8_T_Cell_q0.01.tsv
# Processing Spleen_CD8_T_Cell q0.001
# [Skipped]: Already exists /tmp/overlap_macs2_Spleen_CD8_T_Cell_q0.001.tsv
# Processing Spleen_CD8_T_Cell q0.0001
# [Skipped]: Already exists /tmp/overlap_macs2_Spleen_CD8_T_Cell_q0.0001.tsv
# Processing Blood_Monocyte q0.1
# [Skipped]: Already exists /tmp/overlap_macs2_Blood_Monocyte_q0.1.tsv
# Processing Blood_Monocyte q0.01
# [Skipped]: Already exists /tmp/overlap_macs2_Blood_Monocyte_q0.01.tsv
# Processing Blood_Monocyte q0.001
# [Skipped]: Already exists /tmp/overlap_macs2_Blood_Monocyte_q0.001.tsv
# Processing Blood_Monocyte q0.0001
# [Skipped]: Already exists /tmp/overlap_macs2_Blood_Monocyte_q0.0001.tsv
# [('q0.1', 0), ('q0.01', 1), ('q0.001', 2), ('q0.0001', 3)]

# %% [markdown]
# # SPAN
# `--fragment 0` - in ATAC-Seq we are interested in 5' tags instead of fragment locations.

# %%
import subprocess
import re
from pybedtools import BedTool

SPAN_FOLDER='/mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3'
FDRS = [0.1, 0.01, 0.001, 0.0001]
BINS = [200, 100]
SPAN_JAR = '/mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/span-0.9.3.dev.4502.jar'
CHROM_SIZES = '/mnt/stripe/bio/genomes/mm10/mm10.chrom.sizes'

dfs = pd.DataFrame(columns=['name', 'bin', 'level', 'file', 'peaks'])

# Process different bin/fdr values to estimate peaks numbers
for bin_size in BINS:
    for file in glob.glob(SPAN_FOLDER + '/*.bam'):
        name = next((n for n in NAMES if n in file), None)
        fid = re.sub('\.bam|.*/', '', file)
        for fdr in FDRS:
            print('Processing', file, name, bin_size, fdr)
            peaks_file = next(iter(glob.glob(SPAN_FOLDER + 
                                             '/*{}*_{}*_{}*.peak*'.format(fid, bin_size, fdr))), None)
            if peaks_file:
                print('Peaks file', peaks_file)
            else:
                peaks_file = '{}/{}_{}_{}_5.peak'.format(SPAN_FOLDER, fid, bin_size, fdr)
                command = 'java -jar {} '.format(SPAN_JAR) + \
                'analyze -t {} --chrom.sizes {} --bin {} --fdr {} --gap 5 --fragment 0 --peaks {} '.format(
                    file, CHROM_SIZES, bin_size, fdr, peaks_file) + \
                '--workdir {} --threads 32'.format(SPAN_FOLDER)
                print('Running', command)
                subprocess.run(command, shell=True, check=True)
                print('Peaks file', peaks_file)
            dfs.loc[len(dfs)] = (name, bin_size, fdr, peaks_file, int(BedTool(peaks_file).count()))
                
display(dfs.head())
# Out:
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692210_Thymus_gdT_Cell_ATAC_seq_mm10.bam Thymus_gdT_Cell 200 0.1
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692210_Thymus_gdT_Cell_ATAC_seq_mm10_200_0.1_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692210_Thymus_gdT_Cell_ATAC_seq_mm10.bam Thymus_gdT_Cell 200 0.01
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692210_Thymus_gdT_Cell_ATAC_seq_mm10_200_0.01_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692210_Thymus_gdT_Cell_ATAC_seq_mm10.bam Thymus_gdT_Cell 200 0.001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692210_Thymus_gdT_Cell_ATAC_seq_mm10_200_0.001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692210_Thymus_gdT_Cell_ATAC_seq_mm10.bam Thymus_gdT_Cell 200 0.0001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692210_Thymus_gdT_Cell_ATAC_seq_mm10_200_0.0001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692211_Thymus_gdT_Cell_ATAC_seq_mm10.bam Thymus_gdT_Cell 200 0.1
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692211_Thymus_gdT_Cell_ATAC_seq_mm10_200_0.1_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692211_Thymus_gdT_Cell_ATAC_seq_mm10.bam Thymus_gdT_Cell 200 0.01
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692211_Thymus_gdT_Cell_ATAC_seq_mm10_200_0.01_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692211_Thymus_gdT_Cell_ATAC_seq_mm10.bam Thymus_gdT_Cell 200 0.001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692211_Thymus_gdT_Cell_ATAC_seq_mm10_200_0.001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692211_Thymus_gdT_Cell_ATAC_seq_mm10.bam Thymus_gdT_Cell 200 0.0001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692211_Thymus_gdT_Cell_ATAC_seq_mm10_200_0.0001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692212_Thymus_gdT_Cell_ATAC_seq_mm10.bam Thymus_gdT_Cell 200 0.1
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692212_Thymus_gdT_Cell_ATAC_seq_mm10_200_0.1_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692212_Thymus_gdT_Cell_ATAC_seq_mm10.bam Thymus_gdT_Cell 200 0.01
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692212_Thymus_gdT_Cell_ATAC_seq_mm10_200_0.01_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692212_Thymus_gdT_Cell_ATAC_seq_mm10.bam Thymus_gdT_Cell 200 0.001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692212_Thymus_gdT_Cell_ATAC_seq_mm10_200_0.001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692212_Thymus_gdT_Cell_ATAC_seq_mm10.bam Thymus_gdT_Cell 200 0.0001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692212_Thymus_gdT_Cell_ATAC_seq_mm10_200_0.0001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692213_Thymus_gdT_Cell_ATAC_seq_mm10.bam Thymus_gdT_Cell 200 0.1
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692213_Thymus_gdT_Cell_ATAC_seq_mm10_200_0.1_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692213_Thymus_gdT_Cell_ATAC_seq_mm10.bam Thymus_gdT_Cell 200 0.01
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692213_Thymus_gdT_Cell_ATAC_seq_mm10_200_0.01_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692213_Thymus_gdT_Cell_ATAC_seq_mm10.bam Thymus_gdT_Cell 200 0.001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692213_Thymus_gdT_Cell_ATAC_seq_mm10_200_0.001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692213_Thymus_gdT_Cell_ATAC_seq_mm10.bam Thymus_gdT_Cell 200 0.0001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692213_Thymus_gdT_Cell_ATAC_seq_mm10_200_0.0001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692214_Thymus_gdT_Cell_ATAC_seq_mm10.bam Thymus_gdT_Cell 200 0.1
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692214_Thymus_gdT_Cell_ATAC_seq_mm10_200_0.1_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692214_Thymus_gdT_Cell_ATAC_seq_mm10.bam Thymus_gdT_Cell 200 0.01
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692214_Thymus_gdT_Cell_ATAC_seq_mm10_200_0.01_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692214_Thymus_gdT_Cell_ATAC_seq_mm10.bam Thymus_gdT_Cell 200 0.001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692214_Thymus_gdT_Cell_ATAC_seq_mm10_200_0.001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692214_Thymus_gdT_Cell_ATAC_seq_mm10.bam Thymus_gdT_Cell 200 0.0001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692214_Thymus_gdT_Cell_ATAC_seq_mm10_200_0.0001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692215_Thymus_gdT_Cell_ATAC_seq_mm10.bam Thymus_gdT_Cell 200 0.1
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692215_Thymus_gdT_Cell_ATAC_seq_mm10_200_0.1_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692215_Thymus_gdT_Cell_ATAC_seq_mm10.bam Thymus_gdT_Cell 200 0.01
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692215_Thymus_gdT_Cell_ATAC_seq_mm10_200_0.01_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692215_Thymus_gdT_Cell_ATAC_seq_mm10.bam Thymus_gdT_Cell 200 0.001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692215_Thymus_gdT_Cell_ATAC_seq_mm10_200_0.001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692215_Thymus_gdT_Cell_ATAC_seq_mm10.bam Thymus_gdT_Cell 200 0.0001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692215_Thymus_gdT_Cell_ATAC_seq_mm10_200_0.0001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692222_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 200 0.1
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692222_Spleen_CD8_T_Cell_ATAC_seq_mm10_200_0.1_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692222_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 200 0.01
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692222_Spleen_CD8_T_Cell_ATAC_seq_mm10_200_0.01_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692222_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 200 0.001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692222_Spleen_CD8_T_Cell_ATAC_seq_mm10_200_0.001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692222_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 200 0.0001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692222_Spleen_CD8_T_Cell_ATAC_seq_mm10_200_0.0001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692223_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 200 0.1
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692223_Spleen_CD8_T_Cell_ATAC_seq_mm10_200_0.1_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692223_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 200 0.01
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692223_Spleen_CD8_T_Cell_ATAC_seq_mm10_200_0.01_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692223_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 200 0.001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692223_Spleen_CD8_T_Cell_ATAC_seq_mm10_200_0.001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692223_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 200 0.0001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692223_Spleen_CD8_T_Cell_ATAC_seq_mm10_200_0.0001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692224_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 200 0.1
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692224_Spleen_CD8_T_Cell_ATAC_seq_mm10_200_0.1_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692224_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 200 0.01
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692224_Spleen_CD8_T_Cell_ATAC_seq_mm10_200_0.01_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692224_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 200 0.001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692224_Spleen_CD8_T_Cell_ATAC_seq_mm10_200_0.001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692224_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 200 0.0001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692224_Spleen_CD8_T_Cell_ATAC_seq_mm10_200_0.0001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692225_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 200 0.1
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692225_Spleen_CD8_T_Cell_ATAC_seq_mm10_200_0.1_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692225_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 200 0.01
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692225_Spleen_CD8_T_Cell_ATAC_seq_mm10_200_0.01_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692225_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 200 0.001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692225_Spleen_CD8_T_Cell_ATAC_seq_mm10_200_0.001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692225_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 200 0.0001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692225_Spleen_CD8_T_Cell_ATAC_seq_mm10_200_0.0001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692226_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 200 0.1
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692226_Spleen_CD8_T_Cell_ATAC_seq_mm10_200_0.1_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692226_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 200 0.01
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692226_Spleen_CD8_T_Cell_ATAC_seq_mm10_200_0.01_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692226_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 200 0.001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692226_Spleen_CD8_T_Cell_ATAC_seq_mm10_200_0.001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692226_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 200 0.0001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692226_Spleen_CD8_T_Cell_ATAC_seq_mm10_200_0.0001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692227_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 200 0.1
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692227_Spleen_CD8_T_Cell_ATAC_seq_mm10_200_0.1_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692227_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 200 0.01
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692227_Spleen_CD8_T_Cell_ATAC_seq_mm10_200_0.01_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692227_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 200 0.001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692227_Spleen_CD8_T_Cell_ATAC_seq_mm10_200_0.001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692227_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 200 0.0001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692227_Spleen_CD8_T_Cell_ATAC_seq_mm10_200_0.0001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692228_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 200 0.1
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692228_Spleen_CD8_T_Cell_ATAC_seq_mm10_200_0.1_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692228_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 200 0.01
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692228_Spleen_CD8_T_Cell_ATAC_seq_mm10_200_0.01_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692228_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 200 0.001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692228_Spleen_CD8_T_Cell_ATAC_seq_mm10_200_0.001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692228_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 200 0.0001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692228_Spleen_CD8_T_Cell_ATAC_seq_mm10_200_0.0001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692229_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 200 0.1
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692229_Spleen_CD8_T_Cell_ATAC_seq_mm10_200_0.1_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692229_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 200 0.01
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692229_Spleen_CD8_T_Cell_ATAC_seq_mm10_200_0.01_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692229_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 200 0.001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692229_Spleen_CD8_T_Cell_ATAC_seq_mm10_200_0.001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692229_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 200 0.0001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692229_Spleen_CD8_T_Cell_ATAC_seq_mm10_200_0.0001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692230_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 200 0.1
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692230_Spleen_CD8_T_Cell_ATAC_seq_mm10_200_0.1_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692230_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 200 0.01
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692230_Spleen_CD8_T_Cell_ATAC_seq_mm10_200_0.01_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692230_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 200 0.001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692230_Spleen_CD8_T_Cell_ATAC_seq_mm10_200_0.001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692230_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 200 0.0001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692230_Spleen_CD8_T_Cell_ATAC_seq_mm10_200_0.0001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692231_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 200 0.1
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692231_Spleen_CD8_T_Cell_ATAC_seq_mm10_200_0.1_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692231_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 200 0.01
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692231_Spleen_CD8_T_Cell_ATAC_seq_mm10_200_0.01_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692231_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 200 0.001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692231_Spleen_CD8_T_Cell_ATAC_seq_mm10_200_0.001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692231_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 200 0.0001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692231_Spleen_CD8_T_Cell_ATAC_seq_mm10_200_0.0001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692279_Blood_Monocyte_ATAC_seq_mm10.bam Blood_Monocyte 200 0.1
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692279_Blood_Monocyte_ATAC_seq_mm10_200_0.1_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692279_Blood_Monocyte_ATAC_seq_mm10.bam Blood_Monocyte 200 0.01
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692279_Blood_Monocyte_ATAC_seq_mm10_200_0.01_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692279_Blood_Monocyte_ATAC_seq_mm10.bam Blood_Monocyte 200 0.001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692279_Blood_Monocyte_ATAC_seq_mm10_200_0.001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692279_Blood_Monocyte_ATAC_seq_mm10.bam Blood_Monocyte 200 0.0001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692279_Blood_Monocyte_ATAC_seq_mm10_200_0.0001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692280_Blood_Monocyte_ATAC_seq_mm10.bam Blood_Monocyte 200 0.1
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692280_Blood_Monocyte_ATAC_seq_mm10_200_0.1_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692280_Blood_Monocyte_ATAC_seq_mm10.bam Blood_Monocyte 200 0.01
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692280_Blood_Monocyte_ATAC_seq_mm10_200_0.01_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692280_Blood_Monocyte_ATAC_seq_mm10.bam Blood_Monocyte 200 0.001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692280_Blood_Monocyte_ATAC_seq_mm10_200_0.001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692280_Blood_Monocyte_ATAC_seq_mm10.bam Blood_Monocyte 200 0.0001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692280_Blood_Monocyte_ATAC_seq_mm10_200_0.0001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692281_Blood_Monocyte_ATAC_seq_mm10.bam Blood_Monocyte 200 0.1
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692281_Blood_Monocyte_ATAC_seq_mm10_200_0.1_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692281_Blood_Monocyte_ATAC_seq_mm10.bam Blood_Monocyte 200 0.01
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692281_Blood_Monocyte_ATAC_seq_mm10_200_0.01_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692281_Blood_Monocyte_ATAC_seq_mm10.bam Blood_Monocyte 200 0.001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692281_Blood_Monocyte_ATAC_seq_mm10_200_0.001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692281_Blood_Monocyte_ATAC_seq_mm10.bam Blood_Monocyte 200 0.0001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692281_Blood_Monocyte_ATAC_seq_mm10_200_0.0001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692282_Blood_Monocyte_ATAC_seq_mm10.bam Blood_Monocyte 200 0.1
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692282_Blood_Monocyte_ATAC_seq_mm10_200_0.1_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692282_Blood_Monocyte_ATAC_seq_mm10.bam Blood_Monocyte 200 0.01
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692282_Blood_Monocyte_ATAC_seq_mm10_200_0.01_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692282_Blood_Monocyte_ATAC_seq_mm10.bam Blood_Monocyte 200 0.001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692282_Blood_Monocyte_ATAC_seq_mm10_200_0.001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692282_Blood_Monocyte_ATAC_seq_mm10.bam Blood_Monocyte 200 0.0001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692282_Blood_Monocyte_ATAC_seq_mm10_200_0.0001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692329_Blood_Monocyte_ATAC_seq_mm10.bam Blood_Monocyte 200 0.1
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692329_Blood_Monocyte_ATAC_seq_mm10_200_0.1_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692329_Blood_Monocyte_ATAC_seq_mm10.bam Blood_Monocyte 200 0.01
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692329_Blood_Monocyte_ATAC_seq_mm10_200_0.01_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692329_Blood_Monocyte_ATAC_seq_mm10.bam Blood_Monocyte 200 0.001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692329_Blood_Monocyte_ATAC_seq_mm10_200_0.001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692329_Blood_Monocyte_ATAC_seq_mm10.bam Blood_Monocyte 200 0.0001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692329_Blood_Monocyte_ATAC_seq_mm10_200_0.0001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692330_Blood_Monocyte_ATAC_seq_mm10.bam Blood_Monocyte 200 0.1
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692330_Blood_Monocyte_ATAC_seq_mm10_200_0.1_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692330_Blood_Monocyte_ATAC_seq_mm10.bam Blood_Monocyte 200 0.01
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692330_Blood_Monocyte_ATAC_seq_mm10_200_0.01_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692330_Blood_Monocyte_ATAC_seq_mm10.bam Blood_Monocyte 200 0.001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692330_Blood_Monocyte_ATAC_seq_mm10_200_0.001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692330_Blood_Monocyte_ATAC_seq_mm10.bam Blood_Monocyte 200 0.0001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692330_Blood_Monocyte_ATAC_seq_mm10_200_0.0001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692210_Thymus_gdT_Cell_ATAC_seq_mm10.bam Thymus_gdT_Cell 100 0.1
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692210_Thymus_gdT_Cell_ATAC_seq_mm10_100_0.1_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692210_Thymus_gdT_Cell_ATAC_seq_mm10.bam Thymus_gdT_Cell 100 0.01
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692210_Thymus_gdT_Cell_ATAC_seq_mm10_100_0.01_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692210_Thymus_gdT_Cell_ATAC_seq_mm10.bam Thymus_gdT_Cell 100 0.001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692210_Thymus_gdT_Cell_ATAC_seq_mm10_100_0.001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692210_Thymus_gdT_Cell_ATAC_seq_mm10.bam Thymus_gdT_Cell 100 0.0001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692210_Thymus_gdT_Cell_ATAC_seq_mm10_100_0.0001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692211_Thymus_gdT_Cell_ATAC_seq_mm10.bam Thymus_gdT_Cell 100 0.1
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692211_Thymus_gdT_Cell_ATAC_seq_mm10_100_0.1_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692211_Thymus_gdT_Cell_ATAC_seq_mm10.bam Thymus_gdT_Cell 100 0.01
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692211_Thymus_gdT_Cell_ATAC_seq_mm10_100_0.01_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692211_Thymus_gdT_Cell_ATAC_seq_mm10.bam Thymus_gdT_Cell 100 0.001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692211_Thymus_gdT_Cell_ATAC_seq_mm10_100_0.001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692211_Thymus_gdT_Cell_ATAC_seq_mm10.bam Thymus_gdT_Cell 100 0.0001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692211_Thymus_gdT_Cell_ATAC_seq_mm10_100_0.0001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692212_Thymus_gdT_Cell_ATAC_seq_mm10.bam Thymus_gdT_Cell 100 0.1
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692212_Thymus_gdT_Cell_ATAC_seq_mm10_100_0.1_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692212_Thymus_gdT_Cell_ATAC_seq_mm10.bam Thymus_gdT_Cell 100 0.01
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692212_Thymus_gdT_Cell_ATAC_seq_mm10_100_0.01_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692212_Thymus_gdT_Cell_ATAC_seq_mm10.bam Thymus_gdT_Cell 100 0.001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692212_Thymus_gdT_Cell_ATAC_seq_mm10_100_0.001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692212_Thymus_gdT_Cell_ATAC_seq_mm10.bam Thymus_gdT_Cell 100 0.0001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692212_Thymus_gdT_Cell_ATAC_seq_mm10_100_0.0001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692213_Thymus_gdT_Cell_ATAC_seq_mm10.bam Thymus_gdT_Cell 100 0.1
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692213_Thymus_gdT_Cell_ATAC_seq_mm10_100_0.1_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692213_Thymus_gdT_Cell_ATAC_seq_mm10.bam Thymus_gdT_Cell 100 0.01
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692213_Thymus_gdT_Cell_ATAC_seq_mm10_100_0.01_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692213_Thymus_gdT_Cell_ATAC_seq_mm10.bam Thymus_gdT_Cell 100 0.001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692213_Thymus_gdT_Cell_ATAC_seq_mm10_100_0.001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692213_Thymus_gdT_Cell_ATAC_seq_mm10.bam Thymus_gdT_Cell 100 0.0001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692213_Thymus_gdT_Cell_ATAC_seq_mm10_100_0.0001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692214_Thymus_gdT_Cell_ATAC_seq_mm10.bam Thymus_gdT_Cell 100 0.1
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692214_Thymus_gdT_Cell_ATAC_seq_mm10_100_0.1_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692214_Thymus_gdT_Cell_ATAC_seq_mm10.bam Thymus_gdT_Cell 100 0.01
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692214_Thymus_gdT_Cell_ATAC_seq_mm10_100_0.01_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692214_Thymus_gdT_Cell_ATAC_seq_mm10.bam Thymus_gdT_Cell 100 0.001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692214_Thymus_gdT_Cell_ATAC_seq_mm10_100_0.001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692214_Thymus_gdT_Cell_ATAC_seq_mm10.bam Thymus_gdT_Cell 100 0.0001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692214_Thymus_gdT_Cell_ATAC_seq_mm10_100_0.0001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692215_Thymus_gdT_Cell_ATAC_seq_mm10.bam Thymus_gdT_Cell 100 0.1
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692215_Thymus_gdT_Cell_ATAC_seq_mm10_100_0.1_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692215_Thymus_gdT_Cell_ATAC_seq_mm10.bam Thymus_gdT_Cell 100 0.01
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692215_Thymus_gdT_Cell_ATAC_seq_mm10_100_0.01_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692215_Thymus_gdT_Cell_ATAC_seq_mm10.bam Thymus_gdT_Cell 100 0.001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692215_Thymus_gdT_Cell_ATAC_seq_mm10_100_0.001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692215_Thymus_gdT_Cell_ATAC_seq_mm10.bam Thymus_gdT_Cell 100 0.0001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692215_Thymus_gdT_Cell_ATAC_seq_mm10_100_0.0001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692222_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 100 0.1
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692222_Spleen_CD8_T_Cell_ATAC_seq_mm10_100_0.1_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692222_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 100 0.01
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692222_Spleen_CD8_T_Cell_ATAC_seq_mm10_100_0.01_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692222_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 100 0.001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692222_Spleen_CD8_T_Cell_ATAC_seq_mm10_100_0.001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692222_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 100 0.0001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692222_Spleen_CD8_T_Cell_ATAC_seq_mm10_100_0.0001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692223_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 100 0.1
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692223_Spleen_CD8_T_Cell_ATAC_seq_mm10_100_0.1_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692223_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 100 0.01
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692223_Spleen_CD8_T_Cell_ATAC_seq_mm10_100_0.01_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692223_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 100 0.001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692223_Spleen_CD8_T_Cell_ATAC_seq_mm10_100_0.001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692223_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 100 0.0001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692223_Spleen_CD8_T_Cell_ATAC_seq_mm10_100_0.0001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692224_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 100 0.1
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692224_Spleen_CD8_T_Cell_ATAC_seq_mm10_100_0.1_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692224_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 100 0.01
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692224_Spleen_CD8_T_Cell_ATAC_seq_mm10_100_0.01_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692224_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 100 0.001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692224_Spleen_CD8_T_Cell_ATAC_seq_mm10_100_0.001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692224_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 100 0.0001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692224_Spleen_CD8_T_Cell_ATAC_seq_mm10_100_0.0001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692225_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 100 0.1
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692225_Spleen_CD8_T_Cell_ATAC_seq_mm10_100_0.1_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692225_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 100 0.01
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692225_Spleen_CD8_T_Cell_ATAC_seq_mm10_100_0.01_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692225_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 100 0.001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692225_Spleen_CD8_T_Cell_ATAC_seq_mm10_100_0.001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692225_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 100 0.0001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692225_Spleen_CD8_T_Cell_ATAC_seq_mm10_100_0.0001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692226_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 100 0.1
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692226_Spleen_CD8_T_Cell_ATAC_seq_mm10_100_0.1_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692226_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 100 0.01
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692226_Spleen_CD8_T_Cell_ATAC_seq_mm10_100_0.01_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692226_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 100 0.001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692226_Spleen_CD8_T_Cell_ATAC_seq_mm10_100_0.001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692226_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 100 0.0001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692226_Spleen_CD8_T_Cell_ATAC_seq_mm10_100_0.0001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692227_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 100 0.1
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692227_Spleen_CD8_T_Cell_ATAC_seq_mm10_100_0.1_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692227_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 100 0.01
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692227_Spleen_CD8_T_Cell_ATAC_seq_mm10_100_0.01_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692227_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 100 0.001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692227_Spleen_CD8_T_Cell_ATAC_seq_mm10_100_0.001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692227_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 100 0.0001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692227_Spleen_CD8_T_Cell_ATAC_seq_mm10_100_0.0001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692228_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 100 0.1
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692228_Spleen_CD8_T_Cell_ATAC_seq_mm10_100_0.1_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692228_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 100 0.01
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692228_Spleen_CD8_T_Cell_ATAC_seq_mm10_100_0.01_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692228_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 100 0.001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692228_Spleen_CD8_T_Cell_ATAC_seq_mm10_100_0.001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692228_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 100 0.0001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692228_Spleen_CD8_T_Cell_ATAC_seq_mm10_100_0.0001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692229_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 100 0.1
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692229_Spleen_CD8_T_Cell_ATAC_seq_mm10_100_0.1_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692229_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 100 0.01
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692229_Spleen_CD8_T_Cell_ATAC_seq_mm10_100_0.01_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692229_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 100 0.001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692229_Spleen_CD8_T_Cell_ATAC_seq_mm10_100_0.001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692229_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 100 0.0001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692229_Spleen_CD8_T_Cell_ATAC_seq_mm10_100_0.0001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692230_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 100 0.1
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692230_Spleen_CD8_T_Cell_ATAC_seq_mm10_100_0.1_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692230_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 100 0.01
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692230_Spleen_CD8_T_Cell_ATAC_seq_mm10_100_0.01_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692230_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 100 0.001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692230_Spleen_CD8_T_Cell_ATAC_seq_mm10_100_0.001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692230_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 100 0.0001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692230_Spleen_CD8_T_Cell_ATAC_seq_mm10_100_0.0001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692231_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 100 0.1
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692231_Spleen_CD8_T_Cell_ATAC_seq_mm10_100_0.1_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692231_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 100 0.01
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692231_Spleen_CD8_T_Cell_ATAC_seq_mm10_100_0.01_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692231_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 100 0.001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692231_Spleen_CD8_T_Cell_ATAC_seq_mm10_100_0.001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692231_Spleen_CD8_T_Cell_ATAC_seq_mm10.bam Spleen_CD8_T_Cell 100 0.0001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692231_Spleen_CD8_T_Cell_ATAC_seq_mm10_100_0.0001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692279_Blood_Monocyte_ATAC_seq_mm10.bam Blood_Monocyte 100 0.1
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692279_Blood_Monocyte_ATAC_seq_mm10_100_0.1_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692279_Blood_Monocyte_ATAC_seq_mm10.bam Blood_Monocyte 100 0.01
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692279_Blood_Monocyte_ATAC_seq_mm10_100_0.01_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692279_Blood_Monocyte_ATAC_seq_mm10.bam Blood_Monocyte 100 0.001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692279_Blood_Monocyte_ATAC_seq_mm10_100_0.001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692279_Blood_Monocyte_ATAC_seq_mm10.bam Blood_Monocyte 100 0.0001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692279_Blood_Monocyte_ATAC_seq_mm10_100_0.0001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692280_Blood_Monocyte_ATAC_seq_mm10.bam Blood_Monocyte 100 0.1
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692280_Blood_Monocyte_ATAC_seq_mm10_100_0.1_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692280_Blood_Monocyte_ATAC_seq_mm10.bam Blood_Monocyte 100 0.01
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692280_Blood_Monocyte_ATAC_seq_mm10_100_0.01_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692280_Blood_Monocyte_ATAC_seq_mm10.bam Blood_Monocyte 100 0.001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692280_Blood_Monocyte_ATAC_seq_mm10_100_0.001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692280_Blood_Monocyte_ATAC_seq_mm10.bam Blood_Monocyte 100 0.0001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692280_Blood_Monocyte_ATAC_seq_mm10_100_0.0001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692281_Blood_Monocyte_ATAC_seq_mm10.bam Blood_Monocyte 100 0.1
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692281_Blood_Monocyte_ATAC_seq_mm10_100_0.1_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692281_Blood_Monocyte_ATAC_seq_mm10.bam Blood_Monocyte 100 0.01
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692281_Blood_Monocyte_ATAC_seq_mm10_100_0.01_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692281_Blood_Monocyte_ATAC_seq_mm10.bam Blood_Monocyte 100 0.001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692281_Blood_Monocyte_ATAC_seq_mm10_100_0.001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692281_Blood_Monocyte_ATAC_seq_mm10.bam Blood_Monocyte 100 0.0001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692281_Blood_Monocyte_ATAC_seq_mm10_100_0.0001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692282_Blood_Monocyte_ATAC_seq_mm10.bam Blood_Monocyte 100 0.1
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692282_Blood_Monocyte_ATAC_seq_mm10_100_0.1_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692282_Blood_Monocyte_ATAC_seq_mm10.bam Blood_Monocyte 100 0.01
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692282_Blood_Monocyte_ATAC_seq_mm10_100_0.01_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692282_Blood_Monocyte_ATAC_seq_mm10.bam Blood_Monocyte 100 0.001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692282_Blood_Monocyte_ATAC_seq_mm10_100_0.001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692282_Blood_Monocyte_ATAC_seq_mm10.bam Blood_Monocyte 100 0.0001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692282_Blood_Monocyte_ATAC_seq_mm10_100_0.0001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692329_Blood_Monocyte_ATAC_seq_mm10.bam Blood_Monocyte 100 0.1
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692329_Blood_Monocyte_ATAC_seq_mm10_100_0.1_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692329_Blood_Monocyte_ATAC_seq_mm10.bam Blood_Monocyte 100 0.01
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692329_Blood_Monocyte_ATAC_seq_mm10_100_0.01_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692329_Blood_Monocyte_ATAC_seq_mm10.bam Blood_Monocyte 100 0.001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692329_Blood_Monocyte_ATAC_seq_mm10_100_0.001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692329_Blood_Monocyte_ATAC_seq_mm10.bam Blood_Monocyte 100 0.0001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692329_Blood_Monocyte_ATAC_seq_mm10_100_0.0001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692330_Blood_Monocyte_ATAC_seq_mm10.bam Blood_Monocyte 100 0.1
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692330_Blood_Monocyte_ATAC_seq_mm10_100_0.1_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692330_Blood_Monocyte_ATAC_seq_mm10.bam Blood_Monocyte 100 0.01
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692330_Blood_Monocyte_ATAC_seq_mm10_100_0.01_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692330_Blood_Monocyte_ATAC_seq_mm10.bam Blood_Monocyte 100 0.001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692330_Blood_Monocyte_ATAC_seq_mm10_100_0.001_5.peak
# Processing /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692330_Blood_Monocyte_ATAC_seq_mm10.bam Blood_Monocyte 100 0.0001
# Peaks file /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3/GSM2692330_Blood_Monocyte_ATAC_seq_mm10_100_0.0001_5.peak
#               name  bin   level  \
# 0  Thymus_gdT_Cell  200  0.1000
# 1  Thymus_gdT_Cell  200  0.0100
# 2  Thymus_gdT_Cell  200  0.0010
# 3  Thymus_gdT_Cell  200  0.0001
# 4  Thymus_gdT_Cell  200  0.1000
#
#                                                 file  peaks
# 0  /mnt/stripe/bio/raw-data/geo-samples/PRJNA3929...  49147
# 1  /mnt/stripe/bio/raw-data/geo-samples/PRJNA3929...  38157
# 2  /mnt/stripe/bio/raw-data/geo-samples/PRJNA3929...  32353
# 3  /mnt/stripe/bio/raw-data/geo-samples/PRJNA3929...  28497
# 4  /mnt/stripe/bio/raw-data/geo-samples/PRJNA3929...  59269

# %%
dfs['peaks'] = [int(x) for x in dfs['peaks']]
dfs.groupby(['name', 'bin', 'level'])['peaks'].mean()
# Out:
# name               bin  level
# Blood_Monocyte     100  0.0001     33035.666667
#                         0.0010     36211.500000
#                         0.0100     40698.500000
#                         0.1000     50978.666667
#                    200  0.0001     27587.500000
#                         0.0010     30617.000000
#                         0.0100     34318.833333
#                         0.1000    128425.166667
# Spleen_CD8_T_Cell  100  0.0001     29347.500000
#                         0.0010     31834.200000
#                         0.0100     35534.000000
#                         0.1000     43754.900000
#                    200  0.0001     26502.800000
#                         0.0010     28865.400000
#                         0.0100     32364.100000
#                         0.1000     40039.300000
# Thymus_gdT_Cell    100  0.0001     33586.833333
#                         0.0010     38420.833333
#                         0.0100     45825.500000
#                         0.1000     61818.833333
#                    200  0.0001     29357.166667
#                         0.0010     33687.333333
#                         0.0100     39971.500000
#                         0.1000     52645.500000
# Name: peaks, dtype: float64

# %% [markdown]
# ## SPAN number of peaks

# %%
for bin_size in BINS:
    print('Bin Size', bin_size)
    show_peaks(dfs.loc[dfs['bin']==bin_size], FDRS, log=False, ymax=70000)
# Out:
# Bin Size 200
# [(0.1, 0), (0.01, 1), (0.001, 2), (0.0001, 3)]
# /home/user/anaconda/envs/py35/lib/python3.5/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/user/anaconda/envs/py35/lib/python3.5/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /home/user/anaconda/envs/py35/lib/python3.5/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Bin Size 100
# [(0.1, 0), (0.01, 1), (0.001, 2), (0.0001, 3)]

# %% [markdown]
# ## SPAN overlaps

# %%
for bin_size in BINS:
    print('Bin Size', bin_size)
    show_overlap(dfs.loc[dfs['bin']==bin_size], FDRS, 'span_{}'.format(bin_size), ymax=0.9)
# Out:
# Bin Size 200
# Processing Thymus_gdT_Cell 0.1
# [Skipped]: Already exists /tmp/overlap_span_200_Thymus_gdT_Cell_0.1.tsv
# Processing Thymus_gdT_Cell 0.01
# [Skipped]: Already exists /tmp/overlap_span_200_Thymus_gdT_Cell_0.01.tsv
# Processing Thymus_gdT_Cell 0.001
# [Skipped]: Already exists /tmp/overlap_span_200_Thymus_gdT_Cell_0.001.tsv
# Processing Thymus_gdT_Cell 0.0001
# [Skipped]: Already exists /tmp/overlap_span_200_Thymus_gdT_Cell_0.0001.tsv
# Processing Spleen_CD8_T_Cell 0.1
# [Skipped]: Already exists /tmp/overlap_span_200_Spleen_CD8_T_Cell_0.1.tsv
# Processing Spleen_CD8_T_Cell 0.01
# [Skipped]: Already exists /tmp/overlap_span_200_Spleen_CD8_T_Cell_0.01.tsv
# Processing Spleen_CD8_T_Cell 0.001
# [Skipped]: Already exists /tmp/overlap_span_200_Spleen_CD8_T_Cell_0.001.tsv
# Processing Spleen_CD8_T_Cell 0.0001
# [Skipped]: Already exists /tmp/overlap_span_200_Spleen_CD8_T_Cell_0.0001.tsv
# Processing Blood_Monocyte 0.1
# [Skipped]: Already exists /tmp/overlap_span_200_Blood_Monocyte_0.1.tsv
# Processing Blood_Monocyte 0.01
# [Skipped]: Already exists /tmp/overlap_span_200_Blood_Monocyte_0.01.tsv
# Processing Blood_Monocyte 0.001
# [Skipped]: Already exists /tmp/overlap_span_200_Blood_Monocyte_0.001.tsv
# Processing Blood_Monocyte 0.0001
# [Skipped]: Already exists /tmp/overlap_span_200_Blood_Monocyte_0.0001.tsv
# [(0.1, 0), (0.01, 1), (0.001, 2), (0.0001, 3)]
# Bin Size 100
# Processing Thymus_gdT_Cell 0.1
# Calculating metrics:  /tmp/overlap_span_100_Thymus_gdT_Cell_0.1.tsv
#   [Saved] /tmp/overlap_span_100_Thymus_gdT_Cell_0.1.tsv
# Processing Thymus_gdT_Cell 0.01
# Calculating metrics:  /tmp/overlap_span_100_Thymus_gdT_Cell_0.01.tsv
#   [Saved] /tmp/overlap_span_100_Thymus_gdT_Cell_0.01.tsv
# Processing Thymus_gdT_Cell 0.001
# Calculating metrics:  /tmp/overlap_span_100_Thymus_gdT_Cell_0.001.tsv
#   [Saved] /tmp/overlap_span_100_Thymus_gdT_Cell_0.001.tsv
# Processing Thymus_gdT_Cell 0.0001
# Calculating metrics:  /tmp/overlap_span_100_Thymus_gdT_Cell_0.0001.tsv
#   [Saved] /tmp/overlap_span_100_Thymus_gdT_Cell_0.0001.tsv
# Processing Spleen_CD8_T_Cell 0.1
# Calculating metrics:  /tmp/overlap_span_100_Spleen_CD8_T_Cell_0.1.tsv
#   [Saved] /tmp/overlap_span_100_Spleen_CD8_T_Cell_0.1.tsv
# Processing Spleen_CD8_T_Cell 0.01
# Calculating metrics:  /tmp/overlap_span_100_Spleen_CD8_T_Cell_0.01.tsv
#   [Saved] /tmp/overlap_span_100_Spleen_CD8_T_Cell_0.01.tsv
# Processing Spleen_CD8_T_Cell 0.001
# Calculating metrics:  /tmp/overlap_span_100_Spleen_CD8_T_Cell_0.001.tsv
#   [Saved] /tmp/overlap_span_100_Spleen_CD8_T_Cell_0.001.tsv
# Processing Spleen_CD8_T_Cell 0.0001
# Calculating metrics:  /tmp/overlap_span_100_Spleen_CD8_T_Cell_0.0001.tsv
#   [Saved] /tmp/overlap_span_100_Spleen_CD8_T_Cell_0.0001.tsv
# Processing Blood_Monocyte 0.1
# Calculating metrics:  /tmp/overlap_span_100_Blood_Monocyte_0.1.tsv
#   [Saved] /tmp/overlap_span_100_Blood_Monocyte_0.1.tsv
# Processing Blood_Monocyte 0.01
# Calculating metrics:  /tmp/overlap_span_100_Blood_Monocyte_0.01.tsv
#   [Saved] /tmp/overlap_span_100_Blood_Monocyte_0.01.tsv
# Processing Blood_Monocyte 0.001
# Calculating metrics:  /tmp/overlap_span_100_Blood_Monocyte_0.001.tsv
#   [Saved] /tmp/overlap_span_100_Blood_Monocyte_0.001.tsv
# Processing Blood_Monocyte 0.0001
# Calculating metrics:  /tmp/overlap_span_100_Blood_Monocyte_0.0001.tsv
#   [Saved] /tmp/overlap_span_100_Blood_Monocyte_0.0001.tsv
# [(0.1, 0), (0.01, 1), (0.001, 2), (0.0001, 3)]

# %% [markdown]
# ## SPAN tuned with BIN_SIZE=200,100, 50

# %%
dfm_best = dfm.loc[dfm['level']=='q0.01'].copy()
dfm_best['level'] = 'macs2_q0.01'

dfs200_best = dfs.loc[np.logical_and(dfs['bin']==200, dfs['level']==0.01)][[c for c in dfs.columns if c != 'bin']].copy()
dfs200_best['level'] = 'span_200_q0.01'

dfs100_best = dfs.loc[np.logical_and(dfs['bin']==100, dfs['level']==0.01)][[c for c in dfs.columns if c != 'bin']].copy()
dfs100_best['level'] = 'span_100_q0.01'

# dfs50_best = dfs.loc[np.logical_and(dfs['bin']==50, dfs['level']==0.01)][[c for c in dfs.columns if c != 'bin']].copy()
# dfs50_best['level'] = 'span_50_q0.01'       

# Process SPAN tuned values to estimate peaks numbers
SPAN_200_TUNED='/mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3_200_tuned'
dfs200_tuned = pd.DataFrame(columns=['name', 'level', 'file', 'peaks'])
for peaks_file in glob.glob(SPAN_200_TUNED + '/*.peak'):
    name = file_to_name(peaks_file)
    print('Loading peaks', name, peaks_file)
    dfs200_tuned.loc[len(dfs200_tuned)] = (name, 'span_200_tuned', peaks_file, BedTool(peaks_file).count())

SPAN_100_TUNED='/mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3_100_tuned'
dfs100_tuned = pd.DataFrame(columns=['name', 'level', 'file', 'peaks'])
for peaks_file in glob.glob(SPAN_100_TUNED + '/*.peak'):
    name = file_to_name(peaks_file)
    print('Loading peaks', name, peaks_file)
    dfs100_tuned.loc[len(dfs100_tuned)] = (name, 'span_100_tuned', peaks_file, BedTool(peaks_file).count())

# SPAN_50_TUNED='/mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3_50_tuned'    
# dfs50_tuned = pd.DataFrame(columns=['name', 'level', 'file', 'peaks'])
# for peaks_file in glob.glob(SPAN_50_TUNED + '/*.peak'):
#     name = file_to_name(peaks_file)
#     print('Loading peaks', name, peaks_file)
#     dfs50_tuned.loc[len(dfs50_tuned)] = (name, 'span_50_tuned', peaks_file, BedTool(peaks_file).count())

df_best = pd.concat([dfm_best, dfs200_best, dfs200_tuned, dfs100_best, dfs100_tuned]) #, dfs50_best, dfs50_tuned])
df_best['peaks'] = [int(x) for x in df_best['peaks']]
    
BEST_LEVELS=sorted(list(set(df_best['level'])))
# Out:
# Loading peaks Thymus_gdT_Cell /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3_200_tuned/GSM2692210_Thymus_gdT_Cell_ATAC_seq_mm10_0_200#965ff_1.0E-10_2.peak
# Loading peaks Thymus_gdT_Cell /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3_200_tuned/GSM2692211_Thymus_gdT_Cell_ATAC_seq_mm10_0_200#b8eb3_1.0E-12_2.peak
# Loading peaks Thymus_gdT_Cell /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3_200_tuned/GSM2692212_Thymus_gdT_Cell_ATAC_seq_mm10_0_200#81303_1.0E-6_2.peak
# Loading peaks Thymus_gdT_Cell /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3_200_tuned/GSM2692213_Thymus_gdT_Cell_ATAC_seq_mm10_0_200#8275d_1.0E-6_2.peak
# Loading peaks Thymus_gdT_Cell /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3_200_tuned/GSM2692214_Thymus_gdT_Cell_ATAC_seq_mm10_0_200#d3e8c_1.0E-6_2.peak
# Loading peaks Thymus_gdT_Cell /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3_200_tuned/GSM2692215_Thymus_gdT_Cell_ATAC_seq_mm10_0_200#dbb30_1.0E-12_2.peak
# Loading peaks Spleen_CD8_T_Cell /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3_200_tuned/GSM2692222_Spleen_CD8_T_Cell_ATAC_seq_mm10_0_200#b9a09_1.0E-12_2.peak
# Loading peaks Spleen_CD8_T_Cell /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3_200_tuned/GSM2692223_Spleen_CD8_T_Cell_ATAC_seq_mm10_0_200#a6a63_1.0E-12_2.peak
# Loading peaks Spleen_CD8_T_Cell /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3_200_tuned/GSM2692224_Spleen_CD8_T_Cell_ATAC_seq_mm10_0_200#0d5ca_1.0E-4_2.peak
# Loading peaks Spleen_CD8_T_Cell /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3_200_tuned/GSM2692225_Spleen_CD8_T_Cell_ATAC_seq_mm10_0_200#2c889_1.0E-12_2.peak
# Loading peaks Spleen_CD8_T_Cell /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3_200_tuned/GSM2692226_Spleen_CD8_T_Cell_ATAC_seq_mm10_0_200#6683b_1.0E-6_2.peak
# Loading peaks Spleen_CD8_T_Cell /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3_200_tuned/GSM2692227_Spleen_CD8_T_Cell_ATAC_seq_mm10_0_200#af89e_1.0E-12_2.peak
# Loading peaks Spleen_CD8_T_Cell /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3_200_tuned/GSM2692228_Spleen_CD8_T_Cell_ATAC_seq_mm10_0_200#b4674_1.0E-12_2.peak
# Loading peaks Spleen_CD8_T_Cell /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3_200_tuned/GSM2692229_Spleen_CD8_T_Cell_ATAC_seq_mm10_0_200#71500_1.0E-10_2.peak
# Loading peaks Spleen_CD8_T_Cell /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3_200_tuned/GSM2692230_Spleen_CD8_T_Cell_ATAC_seq_mm10_0_200#ad2db_1.0E-8_2.peak
# Loading peaks Spleen_CD8_T_Cell /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3_200_tuned/GSM2692231_Spleen_CD8_T_Cell_ATAC_seq_mm10_0_200#ed570_1.0E-4_2.peak
# Loading peaks Blood_Monocyte /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3_200_tuned/GSM2692279_Blood_Monocyte_ATAC_seq_mm10_0_200#dbe08_1.0E-12_2.peak
# Loading peaks Blood_Monocyte /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3_200_tuned/GSM2692280_Blood_Monocyte_ATAC_seq_mm10_0_200#74143_1.0E-4_2.peak
# Loading peaks Blood_Monocyte /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3_200_tuned/GSM2692281_Blood_Monocyte_ATAC_seq_mm10_0_200#014e8_1.0E-12_2.peak
# Loading peaks Blood_Monocyte /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3_200_tuned/GSM2692282_Blood_Monocyte_ATAC_seq_mm10_0_200#4b103_1.0E-12_2.peak
# Loading peaks Blood_Monocyte /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3_200_tuned/GSM2692329_Blood_Monocyte_ATAC_seq_mm10_0_200#ae87a_1.0E-12_2.peak
# Loading peaks Blood_Monocyte /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3_200_tuned/GSM2692330_Blood_Monocyte_ATAC_seq_mm10_0_200#8a20a_1.0E-4_2.peak
# Loading peaks Thymus_gdT_Cell /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3_100_tuned/GSM2692210_Thymus_gdT_Cell_ATAC_seq_mm10_0_100#6a3af_1.0E-4_2.peak
# Loading peaks Thymus_gdT_Cell /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3_100_tuned/GSM2692211_Thymus_gdT_Cell_ATAC_seq_mm10_0_100#e8555_1.0E-12_2.peak
# Loading peaks Thymus_gdT_Cell /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3_100_tuned/GSM2692212_Thymus_gdT_Cell_ATAC_seq_mm10_0_100#6b5ff_1.0E-4_2.peak
# Loading peaks Thymus_gdT_Cell /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3_100_tuned/GSM2692213_Thymus_gdT_Cell_ATAC_seq_mm10_0_100#301f7_1.0E-6_2.peak
# Loading peaks Thymus_gdT_Cell /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3_100_tuned/GSM2692214_Thymus_gdT_Cell_ATAC_seq_mm10_0_100#5765c_1.0E-6_2.peak
# Loading peaks Thymus_gdT_Cell /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3_100_tuned/GSM2692215_Thymus_gdT_Cell_ATAC_seq_mm10_0_100#266ae_1.0E-12_2.peak
# Loading peaks Spleen_CD8_T_Cell /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3_100_tuned/GSM2692222_Spleen_CD8_T_Cell_ATAC_seq_mm10_0_100#a582a_1.0E-10_2.peak
# Loading peaks Spleen_CD8_T_Cell /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3_100_tuned/GSM2692223_Spleen_CD8_T_Cell_ATAC_seq_mm10_0_100#931cd_1.0E-12_2.peak
# Loading peaks Spleen_CD8_T_Cell /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3_100_tuned/GSM2692224_Spleen_CD8_T_Cell_ATAC_seq_mm10_0_100#5f546_1.0E-6_2.peak
# Loading peaks Spleen_CD8_T_Cell /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3_100_tuned/GSM2692225_Spleen_CD8_T_Cell_ATAC_seq_mm10_0_100#0705f_1.0E-8_2.peak
# Loading peaks Spleen_CD8_T_Cell /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3_100_tuned/GSM2692226_Spleen_CD8_T_Cell_ATAC_seq_mm10_0_100#b4009_1.0E-6_2.peak
# Loading peaks Spleen_CD8_T_Cell /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3_100_tuned/GSM2692227_Spleen_CD8_T_Cell_ATAC_seq_mm10_0_100#20905_0.01_2.peak
# Loading peaks Spleen_CD8_T_Cell /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3_100_tuned/GSM2692228_Spleen_CD8_T_Cell_ATAC_seq_mm10_0_100#f24b9_1.0E-8_2.peak
# Loading peaks Spleen_CD8_T_Cell /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3_100_tuned/GSM2692229_Spleen_CD8_T_Cell_ATAC_seq_mm10_0_100#94682_1.0E-12_2.peak
# Loading peaks Spleen_CD8_T_Cell /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3_100_tuned/GSM2692230_Spleen_CD8_T_Cell_ATAC_seq_mm10_0_100#8a24d_1.0E-6_2.peak
# Loading peaks Spleen_CD8_T_Cell /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3_100_tuned/GSM2692231_Spleen_CD8_T_Cell_ATAC_seq_mm10_0_100#8f719_1.0E-6_2.peak
# Loading peaks Blood_Monocyte /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3_100_tuned/GSM2692279_Blood_Monocyte_ATAC_seq_mm10_0_100#416a4_1.0E-12_2.peak
# Loading peaks Blood_Monocyte /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3_100_tuned/GSM2692280_Blood_Monocyte_ATAC_seq_mm10_0_100#2f12d_1.0E-6_2.peak
# Loading peaks Blood_Monocyte /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3_100_tuned/GSM2692281_Blood_Monocyte_ATAC_seq_mm10_0_100#521ca_1.0E-12_2.peak
# Loading peaks Blood_Monocyte /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3_100_tuned/GSM2692282_Blood_Monocyte_ATAC_seq_mm10_0_100#92609_1.0E-12_2.peak
# Loading peaks Blood_Monocyte /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3_100_tuned/GSM2692329_Blood_Monocyte_ATAC_seq_mm10_0_100#22a1d_1.0E-10_2.peak
# Loading peaks Blood_Monocyte /mnt/stripe/bio/raw-data/geo-samples/PRJNA392905/bams2process_span_0.9.3_100_tuned/GSM2692330_Blood_Monocyte_ATAC_seq_mm10_0_100#16dad_1.0E-4_2.peak

# %%
df_best.groupby(['name', 'level'])['peaks'].mean()
# Out:
# name               level
# Blood_Monocyte     macs2_q0.01       26945.333333
#                    span_100_q0.01    40698.500000
#                    span_100_tuned    22531.500000
#                    span_200_q0.01    34318.833333
#                    span_200_tuned    18429.833333
# Spleen_CD8_T_Cell  macs2_q0.01       23380.000000
#                    span_100_q0.01    35534.000000
#                    span_100_tuned    24659.100000
#                    span_200_q0.01    32364.100000
#                    span_200_tuned    20297.700000
# Thymus_gdT_Cell    macs2_q0.01       20858.500000
#                    span_100_q0.01    45825.500000
#                    span_100_tuned    24433.166667
#                    span_200_q0.01    39971.500000
#                    span_200_tuned    17909.833333
# Name: peaks, dtype: float64

# %%
show_peaks(df_best, BEST_LEVELS, log=False, ymax=70000)
# Out:
# [('macs2_q0.01', 0), ('span_100_q0.01', 1), ('span_100_tuned', 2), ('span_200_q0.01', 3), ('span_200_tuned', 4)]

# %%
# %%bash
# rm /tmp/overlap_*

# %%
show_overlap(df_best, BEST_LEVELS, 'best', ymax=0.9)
# Out:
# Processing Thymus_gdT_Cell macs2_q0.01
# Calculating metrics:  /tmp/overlap_best_Thymus_gdT_Cell_macs2_q0.01.tsv
#   [Saved] /tmp/overlap_best_Thymus_gdT_Cell_macs2_q0.01.tsv
# Processing Thymus_gdT_Cell span_100_q0.01
# Calculating metrics:  /tmp/overlap_best_Thymus_gdT_Cell_span_100_q0.01.tsv
#   [Saved] /tmp/overlap_best_Thymus_gdT_Cell_span_100_q0.01.tsv
# Processing Thymus_gdT_Cell span_100_tuned
# Calculating metrics:  /tmp/overlap_best_Thymus_gdT_Cell_span_100_tuned.tsv
#   [Saved] /tmp/overlap_best_Thymus_gdT_Cell_span_100_tuned.tsv
# Processing Thymus_gdT_Cell span_200_q0.01
# Calculating metrics:  /tmp/overlap_best_Thymus_gdT_Cell_span_200_q0.01.tsv
#   [Saved] /tmp/overlap_best_Thymus_gdT_Cell_span_200_q0.01.tsv
# Processing Thymus_gdT_Cell span_200_tuned
# Calculating metrics:  /tmp/overlap_best_Thymus_gdT_Cell_span_200_tuned.tsv
#   [Saved] /tmp/overlap_best_Thymus_gdT_Cell_span_200_tuned.tsv
# Processing Spleen_CD8_T_Cell macs2_q0.01
# Calculating metrics:  /tmp/overlap_best_Spleen_CD8_T_Cell_macs2_q0.01.tsv
#   [Saved] /tmp/overlap_best_Spleen_CD8_T_Cell_macs2_q0.01.tsv
# Processing Spleen_CD8_T_Cell span_100_q0.01
# Calculating metrics:  /tmp/overlap_best_Spleen_CD8_T_Cell_span_100_q0.01.tsv
#   [Saved] /tmp/overlap_best_Spleen_CD8_T_Cell_span_100_q0.01.tsv
# Processing Spleen_CD8_T_Cell span_100_tuned
# Calculating metrics:  /tmp/overlap_best_Spleen_CD8_T_Cell_span_100_tuned.tsv
#   [Saved] /tmp/overlap_best_Spleen_CD8_T_Cell_span_100_tuned.tsv
# Processing Spleen_CD8_T_Cell span_200_q0.01
# Calculating metrics:  /tmp/overlap_best_Spleen_CD8_T_Cell_span_200_q0.01.tsv
#   [Saved] /tmp/overlap_best_Spleen_CD8_T_Cell_span_200_q0.01.tsv
# Processing Spleen_CD8_T_Cell span_200_tuned
# Calculating metrics:  /tmp/overlap_best_Spleen_CD8_T_Cell_span_200_tuned.tsv
#   [Saved] /tmp/overlap_best_Spleen_CD8_T_Cell_span_200_tuned.tsv
# Processing Blood_Monocyte macs2_q0.01
# Calculating metrics:  /tmp/overlap_best_Blood_Monocyte_macs2_q0.01.tsv
#   [Saved] /tmp/overlap_best_Blood_Monocyte_macs2_q0.01.tsv
# Processing Blood_Monocyte span_100_q0.01
# Calculating metrics:  /tmp/overlap_best_Blood_Monocyte_span_100_q0.01.tsv
#   [Saved] /tmp/overlap_best_Blood_Monocyte_span_100_q0.01.tsv
# Processing Blood_Monocyte span_100_tuned
# Calculating metrics:  /tmp/overlap_best_Blood_Monocyte_span_100_tuned.tsv
#   [Saved] /tmp/overlap_best_Blood_Monocyte_span_100_tuned.tsv
# Processing Blood_Monocyte span_200_q0.01
# Calculating metrics:  /tmp/overlap_best_Blood_Monocyte_span_200_q0.01.tsv
#   [Saved] /tmp/overlap_best_Blood_Monocyte_span_200_q0.01.tsv
# Processing Blood_Monocyte span_200_tuned
# Calculating metrics:  /tmp/overlap_best_Blood_Monocyte_span_200_tuned.tsv
#   [Saved] /tmp/overlap_best_Blood_Monocyte_span_200_tuned.tsv
# [('macs2_q0.01', 0), ('span_100_q0.01', 1), ('span_100_tuned', 2), ('span_200_q0.01', 3), ('span_200_tuned', 4)]

# %% [markdown]
# # Different visualization + split by tools

# %% [markdown]
# ## Number of peaks

# %%
NAMES_PALETTE = {'Blood_Monocyte': 'lightblue', 'Spleen_CD8_T_Cell': 'lightgreen', 'Thymus_gdT_Cell': 'orange'}

def plot_peaks2(df, levels, title):
    # Create a copy for inplace modifications
    dfw = df.copy()
    # Column to identify all the possibilities
    dfw['ln'] = dfw['name'] + " " + [str(x) for x in dfw['level']]
    lns = len(set(dfw['ln']))
    axs = {}

    fig = plt.figure(figsize=(int(lns*0.7), 5))
    offset = 0
    for l in levels:
        data = dfw.loc[dfw['level'] == l].sort_values(by=['name'])
        xlabels = []
        for n in data['name']:
            if n not in xlabels:
                xlabels.append(n)
        lnd = len(set(data['ln']))
        ax = plt.subplot2grid((1, lns), (0, offset), colspan=lnd)
        sns.barplot(data=data, 
                 x="name", y='peaks',
                 ci="sd", capsize=.2, errwidth=2,
                palette=NAMES_PALETTE,
                 edgecolor="black",
                 ax = ax)

        sns.swarmplot(data=data,
              x="name", y='peaks',
              size=5,
              color='black',
              ax = ax)
        ax.legend().set_visible(False)
        axs[ax] = plt.ylim()
        if offset > 0:
            ax.get_yaxis().set_ticklabels([])
            ax.set_ylabel('')
        else:
            ax.set_ylabel(title)

        offset += lnd
        ax.set_xlabel('')
        ax.set_title(l)
        plt.xticks(range(0, len(xlabels)), xlabels, rotation=90)

    ymin = np.min([v[0] for v in axs.values()])
    ymax = np.max([v[1] for v in axs.values()])

    for ax in axs.keys():
        ax.set_ylim(bottom = ymin, top = ymax)
    plt.tight_layout()

# %%
plot_peaks2(dfm, LEVELS, 'Peaks number MACS2')
plt.show()

plot_peaks2(pd.concat([dfs.loc[dfs['bin']==200], dfs200_tuned]), 
            FDRS + list(set(dfs200_tuned['level'])), 
            'Peaks number SPAN 200')
plt.show()

plot_peaks2(pd.concat([dfs.loc[dfs['bin']==100], dfs100_tuned]), 
            FDRS + list(set(dfs100_tuned['level'])), 
            'Peaks number SPAN 100')
plt.show()

# plot_peaks2(pd.concat([dfs.loc[dfs['bin']==50], dfs50_tuned]), 
#             FDRS + list(set(dfs50_tuned['level'])), 
#             'Peaks number SPAN 50')
# plt.show()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# ## Number of peaks for selected tools

# %%
plot_peaks2(df_best, BEST_LEVELS, 'peaks')
plt.show()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# ## Overlaps

# %%
# %%bash
# rm /tmp/overlap_*

# %%
def plot_overlaps2(df, levels, tool, title):
    # Create a copy for inplace modifications
    dfw = df.copy()
    # Column to identify all the possibilities
    dfw['ln'] = dfw['name'] + " " + [str(x) for x in dfw['level']]
    lns = len(set(dfw['ln']))
    axs = {}

    fig = plt.figure(figsize=(int(lns*0.75), 5))
    offset = 0
    for l in levels:
        data = dfw.loc[dfw['level'] == l]
        lnd = len(set(data['ln']))
        ax = plt.subplot2grid((1, lns), (0, offset), colspan=lnd)
        overlaps={}
        for n in NAMES:
            print('Processing', n, l)
            files = data.loc[data['name'] == n]['file']
            paths = [Path(f) for f in files]
            df_path = '/tmp/overlap_{}_{}_{}.tsv'.format(tool, n, l)
            overlaps[(n, l)] = bm.load_or_build_metrics_table(paths, paths, Path(df_path), jaccard=False)
        dfoverlap = pd.concat([overlap_with_name_level(overlaps, n,  l) for (n, l) in overlaps]).sort_values(by=['name'])        

        xlabels = []
        for n in dfoverlap['name']:
            if n not in xlabels:
                xlabels.append(n)

        sns.barplot(data=dfoverlap, 
                 x="name", y='overlap',
                 ci="sd", capsize=.2, errwidth=2,
                 palette=NAMES_PALETTE, 
                 edgecolor="black",
                 ax = ax)

        sns.swarmplot(data=dfoverlap,
              x="name", y='overlap',
              size=3,
              color='black',
              ax = ax)
        ax.legend().set_visible(False)
        axs[ax] = plt.ylim()
        if offset > 0:
            ax.get_yaxis().set_ticklabels([])
            ax.set_ylabel('')
        else:
            ax.set_ylabel(title)

        offset += lnd
        ax.set_xlabel('')
        ax.set_title(l)
        plt.xticks(range(0, len(xlabels)), xlabels, rotation=90)

    ymin = np.min([v[0] for v in axs.values()])
    ymax = np.max([v[1] for v in axs.values()])

    for ax in axs.keys():
        ax.set_ylim(bottom = ymin, top = ymax)
    plt.tight_layout()

# %%
plot_overlaps2(dfm,  LEVELS, 'macs2', 'Overlap MACS2')
plt.show()

plot_overlaps2(pd.concat([dfs.loc[dfs['bin']==200], dfs200_tuned]), 
            FDRS + list(set(dfs200_tuned['level'])), 
            'span_200', 'Overlap SPAN 200')
plt.show()


plot_overlaps2(pd.concat([dfs.loc[dfs['bin']==100], dfs100_tuned]), 
            FDRS + list(set(dfs100_tuned['level'])), 
            'span_100', 'Overlap SPAN 100')
plt.show()

# plot_overlaps2(pd.concat([dfs.loc[dfs['bin']==50], dfs50_tuned]), 
#             FDRS + list(set(dfs50_tuned['level'])), 
#             'span_50', 'Overlap SPAN 50')
# plt.show()
# Out:
# Processing Thymus_gdT_Cell q0.1
# Calculating metrics:  /tmp/overlap_macs2_Thymus_gdT_Cell_q0.1.tsv
#   [Saved] /tmp/overlap_macs2_Thymus_gdT_Cell_q0.1.tsv
# Processing Spleen_CD8_T_Cell q0.1
# Calculating metrics:  /tmp/overlap_macs2_Spleen_CD8_T_Cell_q0.1.tsv
#   [Saved] /tmp/overlap_macs2_Spleen_CD8_T_Cell_q0.1.tsv
# Processing Blood_Monocyte q0.1
# Calculating metrics:  /tmp/overlap_macs2_Blood_Monocyte_q0.1.tsv
# No handles with labels found to put in legend.
#   [Saved] /tmp/overlap_macs2_Blood_Monocyte_q0.1.tsv
# Processing Thymus_gdT_Cell q0.01
# Calculating metrics:  /tmp/overlap_macs2_Thymus_gdT_Cell_q0.01.tsv
#   [Saved] /tmp/overlap_macs2_Thymus_gdT_Cell_q0.01.tsv
# Processing Spleen_CD8_T_Cell q0.01
# Calculating metrics:  /tmp/overlap_macs2_Spleen_CD8_T_Cell_q0.01.tsv
#   [Saved] /tmp/overlap_macs2_Spleen_CD8_T_Cell_q0.01.tsv
# Processing Blood_Monocyte q0.01
# Calculating metrics:  /tmp/overlap_macs2_Blood_Monocyte_q0.01.tsv
# No handles with labels found to put in legend.
#   [Saved] /tmp/overlap_macs2_Blood_Monocyte_q0.01.tsv
# Processing Thymus_gdT_Cell q0.001
# Calculating metrics:  /tmp/overlap_macs2_Thymus_gdT_Cell_q0.001.tsv
#   [Saved] /tmp/overlap_macs2_Thymus_gdT_Cell_q0.001.tsv
# Processing Spleen_CD8_T_Cell q0.001
# Calculating metrics:  /tmp/overlap_macs2_Spleen_CD8_T_Cell_q0.001.tsv
#   [Saved] /tmp/overlap_macs2_Spleen_CD8_T_Cell_q0.001.tsv
# Processing Blood_Monocyte q0.001
# Calculating metrics:  /tmp/overlap_macs2_Blood_Monocyte_q0.001.tsv
# No handles with labels found to put in legend.
#   [Saved] /tmp/overlap_macs2_Blood_Monocyte_q0.001.tsv
# Processing Thymus_gdT_Cell q0.0001
# Calculating metrics:  /tmp/overlap_macs2_Thymus_gdT_Cell_q0.0001.tsv
#   [Saved] /tmp/overlap_macs2_Thymus_gdT_Cell_q0.0001.tsv
# Processing Spleen_CD8_T_Cell q0.0001
# Calculating metrics:  /tmp/overlap_macs2_Spleen_CD8_T_Cell_q0.0001.tsv
#   [Saved] /tmp/overlap_macs2_Spleen_CD8_T_Cell_q0.0001.tsv
# Processing Blood_Monocyte q0.0001
# Calculating metrics:  /tmp/overlap_macs2_Blood_Monocyte_q0.0001.tsv
# No handles with labels found to put in legend.
#   [Saved] /tmp/overlap_macs2_Blood_Monocyte_q0.0001.tsv
# Processing Thymus_gdT_Cell 0.1
# Calculating metrics:  /tmp/overlap_span_200_Thymus_gdT_Cell_0.1.tsv
#   [Saved] /tmp/overlap_span_200_Thymus_gdT_Cell_0.1.tsv
# Processing Spleen_CD8_T_Cell 0.1
# Calculating metrics:  /tmp/overlap_span_200_Spleen_CD8_T_Cell_0.1.tsv
#   [Saved] /tmp/overlap_span_200_Spleen_CD8_T_Cell_0.1.tsv
# Processing Blood_Monocyte 0.1
# Calculating metrics:  /tmp/overlap_span_200_Blood_Monocyte_0.1.tsv
# No handles with labels found to put in legend.
#   [Saved] /tmp/overlap_span_200_Blood_Monocyte_0.1.tsv
# Processing Thymus_gdT_Cell 0.01
# Calculating metrics:  /tmp/overlap_span_200_Thymus_gdT_Cell_0.01.tsv
#   [Saved] /tmp/overlap_span_200_Thymus_gdT_Cell_0.01.tsv
# Processing Spleen_CD8_T_Cell 0.01
# Calculating metrics:  /tmp/overlap_span_200_Spleen_CD8_T_Cell_0.01.tsv
#   [Saved] /tmp/overlap_span_200_Spleen_CD8_T_Cell_0.01.tsv
# Processing Blood_Monocyte 0.01
# Calculating metrics:  /tmp/overlap_span_200_Blood_Monocyte_0.01.tsv
# No handles with labels found to put in legend.
#   [Saved] /tmp/overlap_span_200_Blood_Monocyte_0.01.tsv
# Processing Thymus_gdT_Cell 0.001
# Calculating metrics:  /tmp/overlap_span_200_Thymus_gdT_Cell_0.001.tsv
#   [Saved] /tmp/overlap_span_200_Thymus_gdT_Cell_0.001.tsv
# Processing Spleen_CD8_T_Cell 0.001
# Calculating metrics:  /tmp/overlap_span_200_Spleen_CD8_T_Cell_0.001.tsv
#   [Saved] /tmp/overlap_span_200_Spleen_CD8_T_Cell_0.001.tsv
# Processing Blood_Monocyte 0.001
# Calculating metrics:  /tmp/overlap_span_200_Blood_Monocyte_0.001.tsv
# No handles with labels found to put in legend.
#   [Saved] /tmp/overlap_span_200_Blood_Monocyte_0.001.tsv
# Processing Thymus_gdT_Cell 0.0001
# Calculating metrics:  /tmp/overlap_span_200_Thymus_gdT_Cell_0.0001.tsv
#   [Saved] /tmp/overlap_span_200_Thymus_gdT_Cell_0.0001.tsv
# Processing Spleen_CD8_T_Cell 0.0001
# Calculating metrics:  /tmp/overlap_span_200_Spleen_CD8_T_Cell_0.0001.tsv
#   [Saved] /tmp/overlap_span_200_Spleen_CD8_T_Cell_0.0001.tsv
# Processing Blood_Monocyte 0.0001
# Calculating metrics:  /tmp/overlap_span_200_Blood_Monocyte_0.0001.tsv
# No handles with labels found to put in legend.
#   [Saved] /tmp/overlap_span_200_Blood_Monocyte_0.0001.tsv
# Processing Thymus_gdT_Cell span_200_tuned
# Calculating metrics:  /tmp/overlap_span_200_Thymus_gdT_Cell_span_200_tuned.tsv
#   [Saved] /tmp/overlap_span_200_Thymus_gdT_Cell_span_200_tuned.tsv
# Processing Spleen_CD8_T_Cell span_200_tuned
# Calculating metrics:  /tmp/overlap_span_200_Spleen_CD8_T_Cell_span_200_tuned.tsv
#   [Saved] /tmp/overlap_span_200_Spleen_CD8_T_Cell_span_200_tuned.tsv
# Processing Blood_Monocyte span_200_tuned
# Calculating metrics:  /tmp/overlap_span_200_Blood_Monocyte_span_200_tuned.tsv
# No handles with labels found to put in legend.
#   [Saved] /tmp/overlap_span_200_Blood_Monocyte_span_200_tuned.tsv
# Processing Thymus_gdT_Cell 0.1
# Calculating metrics:  /tmp/overlap_span_100_Thymus_gdT_Cell_0.1.tsv
#   [Saved] /tmp/overlap_span_100_Thymus_gdT_Cell_0.1.tsv
# Processing Spleen_CD8_T_Cell 0.1
# Calculating metrics:  /tmp/overlap_span_100_Spleen_CD8_T_Cell_0.1.tsv
#   [Saved] /tmp/overlap_span_100_Spleen_CD8_T_Cell_0.1.tsv
# Processing Blood_Monocyte 0.1
# Calculating metrics:  /tmp/overlap_span_100_Blood_Monocyte_0.1.tsv
# No handles with labels found to put in legend.
#   [Saved] /tmp/overlap_span_100_Blood_Monocyte_0.1.tsv
# Processing Thymus_gdT_Cell 0.01
# Calculating metrics:  /tmp/overlap_span_100_Thymus_gdT_Cell_0.01.tsv
#   [Saved] /tmp/overlap_span_100_Thymus_gdT_Cell_0.01.tsv
# Processing Spleen_CD8_T_Cell 0.01
# Calculating metrics:  /tmp/overlap_span_100_Spleen_CD8_T_Cell_0.01.tsv
#   [Saved] /tmp/overlap_span_100_Spleen_CD8_T_Cell_0.01.tsv
# Processing Blood_Monocyte 0.01
# Calculating metrics:  /tmp/overlap_span_100_Blood_Monocyte_0.01.tsv
# No handles with labels found to put in legend.
#   [Saved] /tmp/overlap_span_100_Blood_Monocyte_0.01.tsv
# Processing Thymus_gdT_Cell 0.001
# Calculating metrics:  /tmp/overlap_span_100_Thymus_gdT_Cell_0.001.tsv
#   [Saved] /tmp/overlap_span_100_Thymus_gdT_Cell_0.001.tsv
# Processing Spleen_CD8_T_Cell 0.001
# Calculating metrics:  /tmp/overlap_span_100_Spleen_CD8_T_Cell_0.001.tsv
#   [Saved] /tmp/overlap_span_100_Spleen_CD8_T_Cell_0.001.tsv
# Processing Blood_Monocyte 0.001
# Calculating metrics:  /tmp/overlap_span_100_Blood_Monocyte_0.001.tsv
# No handles with labels found to put in legend.
#   [Saved] /tmp/overlap_span_100_Blood_Monocyte_0.001.tsv
# Processing Thymus_gdT_Cell 0.0001
# Calculating metrics:  /tmp/overlap_span_100_Thymus_gdT_Cell_0.0001.tsv
#   [Saved] /tmp/overlap_span_100_Thymus_gdT_Cell_0.0001.tsv
# Processing Spleen_CD8_T_Cell 0.0001
# Calculating metrics:  /tmp/overlap_span_100_Spleen_CD8_T_Cell_0.0001.tsv
#   [Saved] /tmp/overlap_span_100_Spleen_CD8_T_Cell_0.0001.tsv
# Processing Blood_Monocyte 0.0001
# Calculating metrics:  /tmp/overlap_span_100_Blood_Monocyte_0.0001.tsv
# No handles with labels found to put in legend.
#   [Saved] /tmp/overlap_span_100_Blood_Monocyte_0.0001.tsv
# Processing Thymus_gdT_Cell span_100_tuned
# Calculating metrics:  /tmp/overlap_span_100_Thymus_gdT_Cell_span_100_tuned.tsv
#   [Saved] /tmp/overlap_span_100_Thymus_gdT_Cell_span_100_tuned.tsv
# Processing Spleen_CD8_T_Cell span_100_tuned
# Calculating metrics:  /tmp/overlap_span_100_Spleen_CD8_T_Cell_span_100_tuned.tsv
#   [Saved] /tmp/overlap_span_100_Spleen_CD8_T_Cell_span_100_tuned.tsv
# Processing Blood_Monocyte span_100_tuned
# Calculating metrics:  /tmp/overlap_span_100_Blood_Monocyte_span_100_tuned.tsv
# No handles with labels found to put in legend.
#   [Saved] /tmp/overlap_span_100_Blood_Monocyte_span_100_tuned.tsv

# %% [markdown]
# ## Overlaps  for selected tools

# %%
plot_overlaps2(df_best, BEST_LEVELS, 'best', 'overlap')
plt.show()
# Out:
# Processing Thymus_gdT_Cell macs2_q0.01
# Calculating metrics:  /tmp/overlap_best_Thymus_gdT_Cell_macs2_q0.01.tsv
#   [Saved] /tmp/overlap_best_Thymus_gdT_Cell_macs2_q0.01.tsv
# Processing Spleen_CD8_T_Cell macs2_q0.01
# Calculating metrics:  /tmp/overlap_best_Spleen_CD8_T_Cell_macs2_q0.01.tsv
#   [Saved] /tmp/overlap_best_Spleen_CD8_T_Cell_macs2_q0.01.tsv
# Processing Blood_Monocyte macs2_q0.01
# Calculating metrics:  /tmp/overlap_best_Blood_Monocyte_macs2_q0.01.tsv
# No handles with labels found to put in legend.
#   [Saved] /tmp/overlap_best_Blood_Monocyte_macs2_q0.01.tsv
# Processing Thymus_gdT_Cell span_100_q0.01
# Calculating metrics:  /tmp/overlap_best_Thymus_gdT_Cell_span_100_q0.01.tsv
#   [Saved] /tmp/overlap_best_Thymus_gdT_Cell_span_100_q0.01.tsv
# Processing Spleen_CD8_T_Cell span_100_q0.01
# Calculating metrics:  /tmp/overlap_best_Spleen_CD8_T_Cell_span_100_q0.01.tsv
#   [Saved] /tmp/overlap_best_Spleen_CD8_T_Cell_span_100_q0.01.tsv
# Processing Blood_Monocyte span_100_q0.01
# Calculating metrics:  /tmp/overlap_best_Blood_Monocyte_span_100_q0.01.tsv
# No handles with labels found to put in legend.
#   [Saved] /tmp/overlap_best_Blood_Monocyte_span_100_q0.01.tsv
# Processing Thymus_gdT_Cell span_100_tuned
# Calculating metrics:  /tmp/overlap_best_Thymus_gdT_Cell_span_100_tuned.tsv
#   [Saved] /tmp/overlap_best_Thymus_gdT_Cell_span_100_tuned.tsv
# Processing Spleen_CD8_T_Cell span_100_tuned
# Calculating metrics:  /tmp/overlap_best_Spleen_CD8_T_Cell_span_100_tuned.tsv
#   [Saved] /tmp/overlap_best_Spleen_CD8_T_Cell_span_100_tuned.tsv
# Processing Blood_Monocyte span_100_tuned
# Calculating metrics:  /tmp/overlap_best_Blood_Monocyte_span_100_tuned.tsv
# No handles with labels found to put in legend.
#   [Saved] /tmp/overlap_best_Blood_Monocyte_span_100_tuned.tsv
# Processing Thymus_gdT_Cell span_200_q0.01
# Calculating metrics:  /tmp/overlap_best_Thymus_gdT_Cell_span_200_q0.01.tsv
#   [Saved] /tmp/overlap_best_Thymus_gdT_Cell_span_200_q0.01.tsv
# Processing Spleen_CD8_T_Cell span_200_q0.01
# Calculating metrics:  /tmp/overlap_best_Spleen_CD8_T_Cell_span_200_q0.01.tsv
#   [Saved] /tmp/overlap_best_Spleen_CD8_T_Cell_span_200_q0.01.tsv
# Processing Blood_Monocyte span_200_q0.01
# Calculating metrics:  /tmp/overlap_best_Blood_Monocyte_span_200_q0.01.tsv
# No handles with labels found to put in legend.
#   [Saved] /tmp/overlap_best_Blood_Monocyte_span_200_q0.01.tsv
# Processing Thymus_gdT_Cell span_200_tuned
# Calculating metrics:  /tmp/overlap_best_Thymus_gdT_Cell_span_200_tuned.tsv
#   [Saved] /tmp/overlap_best_Thymus_gdT_Cell_span_200_tuned.tsv
# Processing Spleen_CD8_T_Cell span_200_tuned
# Calculating metrics:  /tmp/overlap_best_Spleen_CD8_T_Cell_span_200_tuned.tsv
#   [Saved] /tmp/overlap_best_Spleen_CD8_T_Cell_span_200_tuned.tsv
# Processing Blood_Monocyte span_200_tuned
# Calculating metrics:  /tmp/overlap_best_Blood_Monocyte_span_200_tuned.tsv
# No handles with labels found to put in legend.
#   [Saved] /tmp/overlap_best_Blood_Monocyte_span_200_tuned.tsv
